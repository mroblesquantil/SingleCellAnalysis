# %%
import argparse
import os

import seaborn as sns
import h5py
import numpy as np
import scanpy as sc

from distributions import *
from top_cells_distributions import *

# %%
input_file = "../Datos de prueba/generados/symsim/clusters_symsim_500_300_5.h5"

# %%
def read_file(input_file: str)-> sc.AnnData:
    """
    Reads the file in h5 format with keys X and y.

    input:
    - input_file: with path

    output:
    - adata: AnnData with the information of counts and clusters.
    """
    with h5py.File(input_file, "r") as file:
        assert 'X' in file.keys() and 'Y' in file.keys()

        X = np.array(file['X'])
        X = X.astype(np.float64)
        y = np.array(file['Y'])
        y = y.astype(np.float64)
    
    print(X.shape, y.shape)

    adata = sc.AnnData(X, dtype=X.dtype)
    adata.obs['Group'] = y

    print( '\n', X.shape, y.shape, '\n')

    return adata

# %%
adata = read_file(input_file)
# Out:
# (300, 500) (14653,)
# /Users/melissa/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 adata = read_file(input_file)
#
# Cell In[19], line 22, in read_file(input_file)
#      19 print(X.shape, y.shape)
#      21 adata = sc.AnnData(X, dtype=X.dtype)
# ---> 22 adata.obs['Group'] = y
#      24 print( '\n', X.shape, y.shape, '\n')
#      26 return adata
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/pandas/core/frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/pandas/core/frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
#    4301     ensure homogeneity.
#    4302     """
# -> 4303     value, refs = self._sanitize_column(value)
#    4305     if (
#    4306         key in self.columns
#    4307         and value.ndim == 1
#    4308         and not isinstance(value.dtype, ExtensionDtype)
#    4309     ):
#    4310         # broadcast across multiple columns if necessary
#    4311         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/pandas/core/frame.py:5042, in DataFrame._sanitize_column(self, value)
#    5039     return _reindex_for_setitem(value, self.index)
#    5041 if is_list_like(value):
# -> 5042     com.require_length_match(value, self.index)
#    5043 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (14653) does not match length of index (300)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 120 × 300
#     obs: 'Group'

# %%
sns.heatmap(adata.X)
# Out:
# <Axes: >

# %%
adata.obs.Group
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 115    3.0
# 116    3.0
# 117    3.0
# 118    3.0
# 119    3.0
# Name: Group, Length: 120, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_counts_per_cell(adata)
#
# File ~/Documents/Tesis/SingleCellAnalysis/src/distributions.py:26, in plot_counts_per_cell(adata, xlim, ylim)
#      12 """
#      13 Creates a joint plot of total counts per cell vs number of genes with counts per cell.
#      14 The values are presented after a logarithmic tranformation.
#    (...)
#      23 - fig: figure with joint plot of the AnnData
#      24 """
#      25 fig = plt.Figure()
# ---> 26 sc.pp.calculate_qc_metrics(adata, inplace=True)
#      28 if xlim == None:
#      29     xlim = (adata.obs.log1p_total_counts.min(), adata.obs.log1p_total_counts.max())
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/scanpy/preprocessing/_qc.py:306, in calculate_qc_metrics(adata, expr_type, var_type, qc_vars, percent_top, layer, use_raw, inplace, log1p, parallel)
#     303 if issparse(X):
#     304     X.eliminate_zeros()
# --> 306 obs_metrics = describe_obs(
#     307     adata,
#     308     expr_type=expr_type,
#     309     var_type=var_type,
#     310     qc_vars=qc_vars,
#     311     percent_top=percent_top,
#     312     inplace=inplace,
#     313     X=X,
#     314     log1p=log1p,
#     315 )
#     316 var_metrics = describe_var(
#     317     adata,
#     318     expr_type=expr_type,
#    (...)
#     322     log1p=log1p,
#     323 )
#     325 if not inplace:
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/scanpy/preprocessing/_qc.py:116, in describe_obs(adata, expr_type, var_type, qc_vars, percent_top, layer, use_raw, log1p, inplace, X, parallel)
#     114 if percent_top:
#     115     percent_top = sorted(percent_top)
# --> 116     proportions = top_segment_proportions(X, percent_top)
#     117     for i, n in enumerate(percent_top):
#     118         obs_metrics[f"pct_{expr_type}_in_top_{n}_{var_type}"] = (
#     119             proportions[:, i] * 100
#     120         )
#
# File ~/miniconda3/envs/env_scRNA/lib/python3.11/site-packages/scanpy/preprocessing/_qc.py:397, in top_segment_proportions(mtx, ns)
#     395 # Pretty much just does dispatch
#     396 if not (max(ns) <= mtx.shape[1] and min(ns) > 0):
# --> 397     raise IndexError("Positions outside range of features.")
#     398 if issparse(mtx):
#     399     if not isspmatrix_csr(mtx):
#
# IndexError: Positions outside range of features.
